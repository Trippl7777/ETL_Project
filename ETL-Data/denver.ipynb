# %%
# Dependencies
from splinter import Browser
from bs4 import BeautifulSoup as bs
from sqlalchemy import create_engine
import numpy as np
import pandas as pd
import requests
import pymongo
from datetime import datetime
import ast

# %%
file = "data/Denver/crime.csv"
data1 = pd.read_csv(file)

# %%
# Column Names from csv
# ----------------------------
# INCIDENT_ID	OFFENSE_ID	OFFENSE_CODE	OFFENSE_CODE_EXTENSION	OFFENSE_TYPE_ID	OFFENSE_CATEGORY_ID	FIRST_OCCURRENCE_DATE	
# LAST_OCCURRENCE_DATE	REPORTED_DATE	INCIDENT_ADDRESS	GEO_X	GEO_Y	GEO_LON	GEO_LAT	DISTRICT_ID	PRECINCT_ID	NEIGHBORHOOD_ID	IS_CRIME	IS_TRAFFIC
data = data1[["INCIDENT_ID", "OFFENSE_CODE", "FIRST_OCCURRENCE_DATE", "OFFENSE_TYPE_ID", "OFFENSE_CATEGORY_ID", "GEO_LAT", "GEO_LON"]].copy()
data.rename(columns={'GEO_LAT': 'latitude', 'GEO_LON': 'longitude'}, inplace=True)
data["city"] = "denver"
data
# Out:
#         INCIDENT_ID  OFFENSE_CODE   FIRST_OCCURRENCE_DATE  \
# 0        2016376978          5213   6/15/2016 11:31:00 PM
# 1       20186000994          2399  10/11/2017 12:30:00 PM
# 2       20166003953          2305     3/4/2016 8:00:00 PM
# 3         201872333          2399    1/30/2018 7:20:00 PM
# 4        2017411405          2303    6/22/2017 8:53:00 PM
# ...             ...           ...                     ...
# 508722   2018836985          5499   12/11/2018 6:06:00 PM
# 508723  20188058998          2602   11/19/2018 4:00:00 PM
# 508724   2018848306          5441   12/16/2018 5:37:00 PM
# 508725   2018831000          5499    12/9/2018 5:21:00 AM
# 508726  20186012081          2304   12/12/2018 4:35:00 PM
#
#                      OFFENSE_TYPE_ID       OFFENSE_CATEGORY_ID   latitude  \
# 0       weapon-unlawful-discharge-of          all-other-crimes  39.773188
# 1                        theft-other                   larceny  39.785649
# 2           theft-items-from-vehicle  theft-from-motor-vehicle  39.663490
# 3                        theft-other                   larceny  39.702698
# 4                     theft-shoplift                   larceny  39.717107
# ...                              ...                       ...        ...
# 508722                    traf-other          all-other-crimes  39.739862
# 508723    theft-fail-return-rent-veh        white-collar-crime  39.836210
# 508724              traffic-accident          traffic-accident  39.687491
# 508725                    traf-other          all-other-crimes  39.738855
# 508726      theft-parts-from-vehicle  theft-from-motor-vehicle  39.678211
#
#          longitude    city
# 0      -104.809881  denver
# 1      -104.781434  denver
# 2      -104.957381  denver
# 3      -104.941440  denver
# 4      -104.955370  denver
# ...            ...     ...
# 508722 -104.948043  denver
# 508723 -104.697230  denver
# 508724 -104.940655  denver
# 508725 -105.029758  denver
# 508726 -104.937077  denver
#
# [508727 rows x 8 columns]

# %%
dates = []
years = []

for date in data["FIRST_OCCURRENCE_DATE"]:
    date = datetime.strptime(date, "%m/%d/%Y %I:%M:%S %p")
    dates.append(date)
    years.append(date.year)
    
data["date"] = dates
data["years"] = years

data = data.loc[(data["years"] >= 2014) & (data["years"] <= 2018)]
data
# Out:
#         INCIDENT_ID  OFFENSE_CODE   FIRST_OCCURRENCE_DATE  \
# 0        2016376978          5213   6/15/2016 11:31:00 PM
# 1       20186000994          2399  10/11/2017 12:30:00 PM
# 2       20166003953          2305     3/4/2016 8:00:00 PM
# 3         201872333          2399    1/30/2018 7:20:00 PM
# 4        2017411405          2303    6/22/2017 8:53:00 PM
# ...             ...           ...                     ...
# 508722   2018836985          5499   12/11/2018 6:06:00 PM
# 508723  20188058998          2602   11/19/2018 4:00:00 PM
# 508724   2018848306          5441   12/16/2018 5:37:00 PM
# 508725   2018831000          5499    12/9/2018 5:21:00 AM
# 508726  20186012081          2304   12/12/2018 4:35:00 PM
#
#                      OFFENSE_TYPE_ID       OFFENSE_CATEGORY_ID   latitude  \
# 0       weapon-unlawful-discharge-of          all-other-crimes  39.773188
# 1                        theft-other                   larceny  39.785649
# 2           theft-items-from-vehicle  theft-from-motor-vehicle  39.663490
# 3                        theft-other                   larceny  39.702698
# 4                     theft-shoplift                   larceny  39.717107
# ...                              ...                       ...        ...
# 508722                    traf-other          all-other-crimes  39.739862
# 508723    theft-fail-return-rent-veh        white-collar-crime  39.836210
# 508724              traffic-accident          traffic-accident  39.687491
# 508725                    traf-other          all-other-crimes  39.738855
# 508726      theft-parts-from-vehicle  theft-from-motor-vehicle  39.678211
#
#          longitude    city                date  years
# 0      -104.809881  denver 2016-06-15 23:31:00   2016
# 1      -104.781434  denver 2017-10-11 12:30:00   2017
# 2      -104.957381  denver 2016-03-04 20:00:00   2016
# 3      -104.941440  denver 2018-01-30 19:20:00   2018
# 4      -104.955370  denver 2017-06-22 20:53:00   2017
# ...            ...     ...                 ...    ...
# 508722 -104.948043  denver 2018-12-11 18:06:00   2018
# 508723 -104.697230  denver 2018-11-19 16:00:00   2018
# 508724 -104.940655  denver 2018-12-16 17:37:00   2018
# 508725 -105.029758  denver 2018-12-09 05:21:00   2018
# 508726 -104.937077  denver 2018-12-12 16:35:00   2018
#
# [450421 rows x 10 columns]

# %% [markdown]
# ----
#
# # Data Munging

# %%
# NA NAN Checking
num_NA = data.isna().sum()
print(num_NA)
print("\nPercentage of NA in whole data: \n" + str(num_NA/data["INCIDENT_ID"].count()))
# Out:
# INCIDENT_ID                 0
# OFFENSE_CODE                0
# FIRST_OCCURRENCE_DATE       0
# OFFENSE_TYPE_ID             0
# OFFENSE_CATEGORY_ID         0
# latitude                 3723
# longitude                3723
# city                        0
# date                        0
# years                       0
# dtype: int64
#
# Percentage of NA in whole data:
# INCIDENT_ID              0.000000
# OFFENSE_CODE             0.000000
# FIRST_OCCURRENCE_DATE    0.000000
# OFFENSE_TYPE_ID          0.000000
# OFFENSE_CATEGORY_ID      0.000000
# latitude                 0.008266
# longitude                0.008266
# city                     0.000000
# date                     0.000000
# years                    0.000000
# dtype: float64

# %%
# Identify rows with Nan in lat/long
data_NA = data.loc[data["latitude"].isna()]
data_NA
# Out:
#         INCIDENT_ID  OFFENSE_CODE  FIRST_OCCURRENCE_DATE    OFFENSE_TYPE_ID  \
# 177       201874540          1109  1/27/2018 10:00:00 PM  sex-aslt-non-rape
# 213       201869284          1109   1/29/2018 1:00:00 PM  sex-aslt-non-rape
# 258      2017787782          1102  11/8/2017 10:00:00 PM      sex-aslt-rape
# 297       201873793          1102  1/30/2018 11:00:00 AM      sex-aslt-rape
# 335     20185000555          1102   12/1/2017 7:00:00 AM  sex-aslt-rape-pot
# ...             ...           ...                    ...                ...
# 508070   2018759402          1102  10/5/2018 12:30:00 AM      sex-aslt-rape
# 508130  20185005313          1102  11/29/2018 1:52:00 PM  sex-aslt-rape-pot
# 508225  20185005437          1102  12/6/2018 11:00:00 AM  sex-aslt-rape-pot
# 508365   2018671712          1102   9/29/2018 8:00:00 PM      sex-aslt-rape
# 508381   2018672245          1102   9/30/2018 6:30:00 PM      sex-aslt-rape
#
#        OFFENSE_CATEGORY_ID  latitude  longitude    city                date  \
# 177         sexual-assault       NaN        NaN  denver 2018-01-27 22:00:00
# 213         sexual-assault       NaN        NaN  denver 2018-01-29 13:00:00
# 258         sexual-assault       NaN        NaN  denver 2017-11-08 22:00:00
# 297         sexual-assault       NaN        NaN  denver 2018-01-30 11:00:00
# 335         sexual-assault       NaN        NaN  denver 2017-12-01 07:00:00
# ...                    ...       ...        ...     ...                 ...
# 508070      sexual-assault       NaN        NaN  denver 2018-10-05 00:30:00
# 508130      sexual-assault       NaN        NaN  denver 2018-11-29 13:52:00
# 508225      sexual-assault       NaN        NaN  denver 2018-12-06 11:00:00
# 508365      sexual-assault       NaN        NaN  denver 2018-09-29 20:00:00
# 508381      sexual-assault       NaN        NaN  denver 2018-09-30 18:30:00
#
#         years
# 177      2018
# 213      2018
# 258      2017
# 297      2018
# 335      2017
# ...       ...
# 508070   2018
# 508130   2018
# 508225   2018
# 508365   2018
# 508381   2018
#
# [3723 rows x 10 columns]

# %%
# With under 0.8266% NaNs, remove rows with NaN in Latitude/Longitude
data = data.dropna()
data
# Out:
#         INCIDENT_ID  OFFENSE_CODE   FIRST_OCCURRENCE_DATE  \
# 0        2016376978          5213   6/15/2016 11:31:00 PM
# 1       20186000994          2399  10/11/2017 12:30:00 PM
# 2       20166003953          2305     3/4/2016 8:00:00 PM
# 3         201872333          2399    1/30/2018 7:20:00 PM
# 4        2017411405          2303    6/22/2017 8:53:00 PM
# ...             ...           ...                     ...
# 508722   2018836985          5499   12/11/2018 6:06:00 PM
# 508723  20188058998          2602   11/19/2018 4:00:00 PM
# 508724   2018848306          5441   12/16/2018 5:37:00 PM
# 508725   2018831000          5499    12/9/2018 5:21:00 AM
# 508726  20186012081          2304   12/12/2018 4:35:00 PM
#
#                      OFFENSE_TYPE_ID       OFFENSE_CATEGORY_ID   latitude  \
# 0       weapon-unlawful-discharge-of          all-other-crimes  39.773188
# 1                        theft-other                   larceny  39.785649
# 2           theft-items-from-vehicle  theft-from-motor-vehicle  39.663490
# 3                        theft-other                   larceny  39.702698
# 4                     theft-shoplift                   larceny  39.717107
# ...                              ...                       ...        ...
# 508722                    traf-other          all-other-crimes  39.739862
# 508723    theft-fail-return-rent-veh        white-collar-crime  39.836210
# 508724              traffic-accident          traffic-accident  39.687491
# 508725                    traf-other          all-other-crimes  39.738855
# 508726      theft-parts-from-vehicle  theft-from-motor-vehicle  39.678211
#
#          longitude    city                date  years
# 0      -104.809881  denver 2016-06-15 23:31:00   2016
# 1      -104.781434  denver 2017-10-11 12:30:00   2017
# 2      -104.957381  denver 2016-03-04 20:00:00   2016
# 3      -104.941440  denver 2018-01-30 19:20:00   2018
# 4      -104.955370  denver 2017-06-22 20:53:00   2017
# ...            ...     ...                 ...    ...
# 508722 -104.948043  denver 2018-12-11 18:06:00   2018
# 508723 -104.697230  denver 2018-11-19 16:00:00   2018
# 508724 -104.940655  denver 2018-12-16 17:37:00   2018
# 508725 -105.029758  denver 2018-12-09 05:21:00   2018
# 508726 -104.937077  denver 2018-12-12 16:35:00   2018
#
# [446698 rows x 10 columns]

# %%
# data_2014 = pd.DataFrame()
# data_2015 = pd.DataFrame()
# data_2016 = pd.DataFrame()
# data_2017 = pd.DataFrame()
# data_2018 = pd.DataFrame()

# data_2014 = data.loc[data["years"] == 2014]
# print(data_2014)
# data_2015 = data.loc[data["years"] == 2015]
# print(data_2015)
# data_2016 = data.loc[data["years"] == 2016]
# print(data_2016)
# data_2017 = data.loc[data["years"] == 2017]
# print(data_2017)
# data_2018 = data.loc[data["years"] == 2018]
# data_2018

# %%
# def reformat_datetime(df):
#     datetimes = []
#     for d,t  in zip(df["date"], df["Time Occurred"]):
# #         print(d)
# #         print(type(d))
#     #     datetime = (datetime.strftime(d, format='%Y-%m-%d') + " " + str(t))
#         d = datetime.strptime(str(d), "%Y-%m-%d %H:%M:%S")
#         date_time = datetime.strftime(d, format='%Y-%m-%d') + "T" + str((int(t/100))) + ":00:00"
#     #     datetime = d + " " + t
#         datetimes.append(date_time)
#     df["date_time"] = datetimes
#     return df

# def reformat_datetime(df):
#     datetimes = []
#     for d in df["date"]:
#         date_time = datetime.strftime(d, format='%Y-%m-%dT%H:00:00')
#         datetimes.append(date_time)
#     df["date_time"] = datetimes
#     return df

def reformat_datetime(df):
    dates = []
    times = []
    for d in df["date"]:
        dy = datetime.strftime(d, format='%Y-%m-%d')
        ti = datetime.strftime(d, format='%H')
        dates.append(dy)
        times.append(ti)
    df["date"] = dates
    df["time"] = times
    return df

# %%
data_denver = reformat_datetime(data)
data_denver
# Out:
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#         INCIDENT_ID  OFFENSE_CODE   FIRST_OCCURRENCE_DATE  \
# 0        2016376978          5213   6/15/2016 11:31:00 PM
# 1       20186000994          2399  10/11/2017 12:30:00 PM
# 2       20166003953          2305     3/4/2016 8:00:00 PM
# 3         201872333          2399    1/30/2018 7:20:00 PM
# 4        2017411405          2303    6/22/2017 8:53:00 PM
# ...             ...           ...                     ...
# 508722   2018836985          5499   12/11/2018 6:06:00 PM
# 508723  20188058998          2602   11/19/2018 4:00:00 PM
# 508724   2018848306          5441   12/16/2018 5:37:00 PM
# 508725   2018831000          5499    12/9/2018 5:21:00 AM
# 508726  20186012081          2304   12/12/2018 4:35:00 PM
#
#                      OFFENSE_TYPE_ID       OFFENSE_CATEGORY_ID   latitude  \
# 0       weapon-unlawful-discharge-of          all-other-crimes  39.773188
# 1                        theft-other                   larceny  39.785649
# 2           theft-items-from-vehicle  theft-from-motor-vehicle  39.663490
# 3                        theft-other                   larceny  39.702698
# 4                     theft-shoplift                   larceny  39.717107
# ...                              ...                       ...        ...
# 508722                    traf-other          all-other-crimes  39.739862
# 508723    theft-fail-return-rent-veh        white-collar-crime  39.836210
# 508724              traffic-accident          traffic-accident  39.687491
# 508725                    traf-other          all-other-crimes  39.738855
# 508726      theft-parts-from-vehicle  theft-from-motor-vehicle  39.678211
#
#          longitude    city        date  years time
# 0      -104.809881  denver  2016-06-15   2016   23
# 1      -104.781434  denver  2017-10-11   2017   12
# 2      -104.957381  denver  2016-03-04   2016   20
# 3      -104.941440  denver  2018-01-30   2018   19
# 4      -104.955370  denver  2017-06-22   2017   20
# ...            ...     ...         ...    ...  ...
# 508722 -104.948043  denver  2018-12-11   2018   18
# 508723 -104.697230  denver  2018-11-19   2018   16
# 508724 -104.940655  denver  2018-12-16   2018   17
# 508725 -105.029758  denver  2018-12-09   2018   05
# 508726 -104.937077  denver  2018-12-12   2018   16
#
# [446698 rows x 11 columns]

# %% [markdown]
# ----
#
# # Final view of date_time into weather data datetime format

# %%
data_denver.rename(columns={"OFFENSE_CODE": "code"}, inplace=True)
data_denver = data_denver[["city", "code", "date", "time", "latitude", "longitude"]].copy()
# data_denver.to_csv (r'data/Denver/data_denver.csv', index = None, header=True)

data_denver
# Out:
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/frame.py:4218: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(**kwargs)
#           city  code        date time   latitude   longitude
# 0       denver  5213  2016-06-15   23  39.773188 -104.809881
# 1       denver  2399  2017-10-11   12  39.785649 -104.781434
# 2       denver  2305  2016-03-04   20  39.663490 -104.957381
# 3       denver  2399  2018-01-30   19  39.702698 -104.941440
# 4       denver  2303  2017-06-22   20  39.717107 -104.955370
# ...        ...   ...         ...  ...        ...         ...
# 508722  denver  5499  2018-12-11   18  39.739862 -104.948043
# 508723  denver  2602  2018-11-19   16  39.836210 -104.697230
# 508724  denver  5441  2018-12-16   17  39.687491 -104.940655
# 508725  denver  5499  2018-12-09   05  39.738855 -105.029758
# 508726  denver  2304  2018-12-12   16  39.678211 -104.937077
#
# [446698 rows x 6 columns]

# %%
# df_years = [data_2014, data_2015, data_2016, data_2017, data_2018]

# for i, yr in enumerate(df_years):
#     df = reformat_datetime(yr)
#     if i == 0:
#         data_2014_1 = df.copy()
#     elif i ==1:
#         data_2015_1 = df.copy()
#     elif i ==2:
#         data_2016_1 = df.copy()
#     elif i ==3:
#         data_2017_1 = df.copy()
#     elif i ==4:
#         data_2018_1 = df.copy()

# %% [markdown]
# ----
#
# # Final DFs per year

# %%
data_2014_1

# %%
data_2015_1

# %%
data_2016_1

# %%
data_2017_1

# %%
data_2018_1

# %%
# .to_csv(index=False)
data_2014_1.to_csv (r'data/Denver/data_2014.csv', index = None, header=True)
data_2015_1.to_csv (r'data/Denver/data_2015.csv', index = None, header=True)
data_2016_1.to_csv (r'data/Denver/data_2016.csv', index = None, header=True)
data_2017_1.to_csv (r'data/Denver/data_2017.csv', index = None, header=True)
data_2018_1.to_csv (r'data/Denver/data_2018.csv', index = None, header=True)
